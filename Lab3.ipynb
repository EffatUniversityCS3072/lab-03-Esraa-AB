# %%
# Esraa Basalamah
# S21107013

# %% [markdown]
# ## Lab 3: pandas
#
# #### Introduction
#
# We will examine a dataset containing characteristics of lego sets manufactured between 1961 and 2019 from the BRICKSET website. Variables in the dataset are described below.
#
# | VARIABLE             |      DESCRIPTION             |
# |:----------|:-------------|
# | ID |  set id |
# | Name |    name of set   |
# | Themegroup | themegroup of set |
# | Theme |  theme of set |
# | Subtheme |    subtheme of set   |
# | Year | year released |
# | Pieces |  number of pieces |
# | Minifig |    number of minifigs   |
# | Package | type of packaging |
# | Retail_Price |  recommended retail pri
#
#
#
# Load pandas to read in the data and save it as dataframe named lego.

# %%
import pandas as pd

lego = pd.read_csv('lego.csv')

# %% [markdown]
# #### Question 1:
# Some sets have missing information for retail_price or pieces or both. This could be because the sets are free (giveaways), they aren’t traditional lego sets (comic books, etc) or just because the information is missing. Filter the lego dataset based on the specifications below and save the result as lego. Hence, you will overwrite the original lego object. In addition, describe the implications of removing these sets.
#
# Your new lego (data frame) should have:
#
# • no missing pieces
#
# • only contain sets with a nonzero number of pieces
#
# • no missing retail_price
#
# • only contain sets with a nonzero retail_price
#
# • no missing year
#
# - Print out the shape of the dataframe after cleaning the dataset.
# -

# %%
# Write your answer here
# Print the shape (rows, columns) of the 'lego' DataFrame
print(lego.shape)

# Remove rows with any missing values in the 'lego' DataFrame and assign the result to 'lego2'
lego2 = lego.dropna()
# Print the new shape of 'lego2' after dropping rows with missing values
print(lego2.shape)

# Filter 'lego2' to keep only rows where the number of pieces is greater than 0
lego2 = lego2.loc[lego2.pieces > 0, :]
# Print the shape of 'lego2' after filtering rows based on the 'pieces' column
print(lego2.shape)

# Further filter 'lego2' to keep only rows where the retail price is greater than 0
lego2 = lego2.loc[lego2.retail_price > 0, :]
# Print the shape of 'lego2' after filtering rows based on the 'retail_price' column
print(lego2.shape)
# Out:
# (12214, 10)
# (4360, 10)
# (4360, 10)
# (4277, 10)

# %%
lego2.head(15)
# Out:
#          id                                       name     themegroup  \
# 1   10264-1                              Corner Garage   Model making
# 2   10265-1                               Ford Mustang   Model making
# 3   10766-1                                 Woody & RC       Licensed
# 4   10769-1                                RV Vacation       Licensed
# 5   10770-1             Buzz & Woody's Carnival Mania!       Licensed
# 6   10771-1                    Carnival Thrill Coaster       Licensed
# 13  10894-1                                      Train     Pre-school
# 27  21043-1                              San Francisco   Model making
# 28  21044-1                                      Paris   Model making
# 29  21148-1         Minecraft Steve BigFig with Parrot       Licensed
# 30  21149-1         Minecraft Alex BigFig with Chicken       Licensed
# 31  21150-1  Minecraft Skeleton BigFig with Magma Cube       Licensed
# 32  21151-1                             The End Battle       Licensed
# 33  21152-1                                Pirate Ship       Licensed
# 34  21316-1                            The Flintstones  Miscellaneous
#
#              theme           subtheme    year  pieces  minifigs package  \
# 1   Creator Expert  Modular Buildings  2019.0  2569.0         6     Box
# 2   Creator Expert           Vehicles  2019.0  1471.0         0     Box
# 3        Toy Story        Toy Story 4  2019.0    69.0         0     Box
# 4        Toy Story        Toy Story 4  2019.0   178.0         0     Box
# 5        Toy Story        Toy Story 4  2019.0   230.0         0     Box
# 6        Toy Story        Toy Story 4  2019.0    98.0         0     Box
# 13           Duplo          Toy Story  2019.0    21.0         0     Box
# 27    Architecture           Skylines  2019.0   565.0         0     Box
# 28    Architecture           Skylines  2019.0   649.0         0     Box
# 29       Minecraft   Bigfigs Series 1  2019.0   159.0         0     Box
# 30       Minecraft   Bigfigs Series 1  2019.0   160.0         0     Box
# 31       Minecraft   Bigfigs Series 1  2019.0   142.0         0     Box
# 32       Minecraft      Minifig-scale  2019.0   222.0         2     Box
# 33       Minecraft      Minifig-scale  2019.0   386.0         3     Box
# 34           Ideas           Licensed  2019.0   748.0         4     Box
#
#     retail_price
# 1         199.99
# 2         149.99
# 3           9.99
# 4          34.99
# 5          49.99
# 6          19.99
# 13         19.99
# 27         49.99
# 28         49.99
# 29         14.99
# 30         14.99
# 31         14.99
# 32         19.99
# 33         39.99
# 34         59.99

# %%
lego2.theme.unique()
# Out:
# array(['Creator Expert', 'Toy Story', 'Duplo', 'Architecture',
#        'Minecraft', 'Ideas', 'City', 'BrickHeadz', 'Ninjago',
#        'The Lego Movie 2: The Second Part', 'Star Wars',
#        'Speed Champions', 'Jurassic World', 'Marvel Super Heroes',
#        'DC Comics Super Heroes', 'Classic', 'Juniors', 'Wizarding World',
#        'Creator', 'Miscellaneous', 'Seasonal', 'Promotional', 'Disney',
#        'Unikitty', 'Friends', 'The LEGO Ninjago Movie',
#        'Collectable Minifigures', 'Nexo Knights', 'The LEGO Batman Movie',
#        'Pirates of the Caribbean', 'Dimensions', 'Mixels', 'Bionicle',
#        'Legends of Chima', 'Education', 'Teenage Mutant Ninja Turtles',
#        'The LEGO Movie', 'The Hobbit', 'The Lord of the Rings', 'Space',
#        'Mindstorms', 'Games', 'Castle', 'Monster Fighters',
#        'Bricks and More', 'Cars', 'Harry Potter', 'Racers',
#        'Power Functions', 'Indiana Jones', 'Pirates', 'Factory',
#        'Exo-Force', 'Trains', 'Sports', 'Town', 'World City',
#        'Alpha Team', 'Spider-Man', 'Bulk Bricks', 'Explore',
#        'Adventurers', 'Studios', 'Western', 'Technic', 'Basic',
#        'Aquazone', 'Service Packs', 'Time Cruisers', 'Assorted', 'Books',
#        'Samsonite', 'LEGOLAND'], dtype=object)

# %% [markdown]
# #### Question 2:
# Arrange the dataset in descending order of retail_price and print the first three rows. Report in words the names of the three most expensive lego sets, their prices, and how many pieces each has.

# %%
# Write your answer here
lego2.sort_values(by='retail_price', ascending = False).head(3)
# Out:
#            id                                    name themegroup      theme  \
# 1434  75192-1                       Millennium Falcon   Licensed  Star Wars
# 5944  10179-1  Ultimate Collector's Millennium Falcon   Licensed  Star Wars
# 2065  75159-1                              Death Star   Licensed  Star Wars
#
#                        subtheme    year  pieces  minifigs package  \
# 1434  Ultimate Collector Series  2017.0  7541.0         8     Box
# 5944  Ultimate Collector Series  2007.0  5197.0         5     Box
# 2065  Ultimate Collector Series  2016.0  4016.0        27     Box
#
#       retail_price
# 1434        799.99
# 5944        499.99
# 2065        499.99

# %% [markdown]
# #### Question 3:
#
# It appears that the most expensive sets generally have more pieces. Create a new variable (column) price_per_piece, representing the price in dollars per piece for each of the sets. Save the result as lego2. Hence, you will overwrite the current lego object.

# %%
# Write your answer here
# Calculate price per piece
lego2['price_per_piece'] = lego2.retail_price / lego2.pieces

# Show first rows
lego2.head()
# Out:
#         id                            name    themegroup           theme  \
# 1  10264-1                   Corner Garage  Model making  Creator Expert
# 2  10265-1                    Ford Mustang  Model making  Creator Expert
# 3  10766-1                      Woody & RC      Licensed       Toy Story
# 4  10769-1                     RV Vacation      Licensed       Toy Story
# 5  10770-1  Buzz & Woody's Carnival Mania!      Licensed       Toy Story
#
#             subtheme    year  pieces  minifigs package  retail_price  \
# 1  Modular Buildings  2019.0  2569.0         6     Box        199.99
# 2           Vehicles  2019.0  1471.0         0     Box        149.99
# 3        Toy Story 4  2019.0    69.0         0     Box          9.99
# 4        Toy Story 4  2019.0   178.0         0     Box         34.99
# 5        Toy Story 4  2019.0   230.0         0     Box         49.99
#
#    price_per_piece
# 1         0.077847
# 2         0.101965
# 3         0.144783
# 4         0.196573
# 5         0.217348

# %% [markdown]
# #### Question 4:
#
# Arrange the lego2 dataset in descending order of price_per_piece and return only the columns: name, themegroup, theme, pieces, price_per_piece, and the first five rows. What do you notice about these sets?

# %%
# Write your answer here
# Sort by price per piece in descending order
lego2 = lego2.sort_values(by = 'price_per_piece', ascending = False)

# Display top 5 rows with selected columns
lego2.loc[:, [ 'name', 'themegroup', 'theme', 'pieces', 'price_per_piece'] ].head(5)
# Out:
#                                        name themegroup            theme  \
# 5551               Rechargeable Battery Box  Technical  Power Functions
# 5553                     Transformer 10V DC  Technical  Power Functions
# 5616              Collectable Display Set 2   Licensed        Star Wars
# 8694                     Temperature Sensor  Technical       Mindstorms
# 7540  Robotics Invention System Upgrade Kit  Technical       Mindstorms
#
#       pieces  price_per_piece
# 5551     1.0           49.990
# 5553     1.0           29.990
# 5616     2.0           24.995
# 8694     1.0           24.000
# 7540     1.0           20.000

# %% [markdown]
# #### Question 5:
#
# What is the mean price_per_piece for the top 40 'Toy Story' sets in terms of price_per_piece?

# %%
# Write your answer here
# Calculate the mean price per piece for 'Toy Story' theme
lego2.loc[lego2.theme == 'Toy Story', :].price_per_piece.mean()
# Out:
# 0.16089862892544177

# %% [markdown]
# #### Question 6:
#
# What are the unique themes in the lego dataset?

# %%
# Write your answer here
lego2.theme.unique().size
# Out:
# 73
